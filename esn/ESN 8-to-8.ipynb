# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, SimpleRNN
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
from keras.layers import Dense, LSTM, TimeDistributed
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv(filepath_or_buffer="./Data/clean_data.csv", index_col="date")

# %%
data.head()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU  spindx GOLDPMGBD228NLBM  exalus  \
# date
# 19870520       8.05        8.92        18.63  278.21          475.250  1.3820
# 19870521       8.06        8.87        18.45  280.17          469.100  1.3864
# 19870522       7.97        8.78        18.55  282.16          466.500  1.3883
# 19870526       7.79        8.55        18.63  289.11          449.000  1.4029
# 19870527       7.84        8.60        18.60  288.73          449.500  1.3988
#
#           exjpus  exukus
# date
# 19870520  139.78  0.5942
# 19870521  140.45  0.5956
# 19870522  140.60  0.5977
# 19870526  143.30  0.6120
# 19870527  143.52  0.6200

# %%
data.tail()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU   spindx GOLDPMGBD228NLBM  \
# date
# 20181029       2.81        3.08        77.56  2641.25          1230.80
# 20181030       2.84        3.12        75.68  2682.63          1225.40
# 20181031       2.87        3.15        74.84  2711.74          1214.95
# 20181101       2.84        3.14        71.25  2740.37          1231.15
# 20181102       2.91        3.22        71.11  2723.06          1232.10
#
#           exalus  exjpus  exukus
# date
# 20181029  1.4136  112.49  0.7808
# 20181030  1.4061  112.76  0.7855
# 20181031  1.4104  112.86  0.7825
# 20181101  1.3910  112.79  0.7708
# 20181102  1.3891  113.09  0.7713

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7931 non-null object
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7931 non-null object
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 557.6+ KB

# %%
data = data.apply(pd.to_numeric, errors = "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7858 non-null float64
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7734 non-null float64
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(8)
# memory usage: 557.6 KB

# %%
data['spindx'].replace(0, np.nan, inplace=True)
data['spindx'].fillna(method='ffill', inplace=True)

# %%
#reshaping prediction value into value range -1 to 1
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # MULTIVARIATE PREDICTION (WITH LOOKBACK AND TIMESTEPS)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
data.columns
#values = data[['exukus'] + ['Volume (BTC)'] + ['Volume (Currency)']].values
#values = values.astype('float32')
# Out:
# Index(['TCMNOM_Y2', 'TCMNOM_Y10', 'DCOILBRENTEU', 'spindx', 'GOLDPMGBD228NLBM',
#        'exalus', 'exjpus', 'exukus'],
#       dtype='object')

# %%
number_of_variables = 8
values = data[['spindx'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10'] + ['DCOILBRENTEU'] + ['GOLDPMGBD228NLBM'] + ['exalus'] + ['exjpus'] + ['exukus']].values
values = values.astype('float32')

# %%
values
# Out:
# array([[2.78210e+02, 8.05000e+00, 8.92000e+00, ..., 1.38200e+00,
#         1.39780e+02, 5.94200e-01],
#        [2.80170e+02, 8.06000e+00, 8.87000e+00, ..., 1.38640e+00,
#         1.40450e+02, 5.95600e-01],
#        [2.82160e+02, 7.97000e+00, 8.78000e+00, ..., 1.38830e+00,
#         1.40600e+02, 5.97700e-01],
#        ...,
#        [2.71174e+03, 2.87000e+00, 3.15000e+00, ..., 1.41040e+00,
#         1.12860e+02, 7.82500e-01],
#        [2.74037e+03, 2.84000e+00, 3.14000e+00, ..., 1.39100e+00,
#         1.12790e+02, 7.70800e-01],
#        [2.72306e+03, 2.91000e+00, 3.22000e+00, ..., 1.38910e+00,
#         1.13090e+02, 7.71300e-01]], dtype=float32)

# %%
look_back = 3 
time_steps = 1
series_to_supervised(values, look_back, time_steps)
reframed = series_to_supervised(values, look_back, time_steps)
reframed.tail()
# Out:
#         var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)    var5(t-3)  var6(t-3)  \
# 7926  2656.100098       2.84       3.10  77.339996  1230.550049     1.4140
# 7927  2705.570068       2.86       3.14  77.300003  1230.800049     1.4116
# 7928  2658.689941       2.81       3.08  77.400002  1233.849976     1.4108
# 7929  2641.250000       2.81       3.08  77.559998  1230.800049     1.4136
# 7930  2682.629883       2.84       3.12  75.680000  1225.400024     1.4061
#
#        var7(t-3)  var8(t-3)    var1(t-2)  var2(t-2)  ...   var7(t-1)  \
# 7926  112.580002     0.7753  2705.570068       2.86  ...  111.650002
# 7927  112.540001     0.7796  2658.689941       2.81  ...  112.489998
# 7928  111.650002     0.7797  2641.250000       2.81  ...  112.760002
# 7929  112.489998     0.7808  2682.629883       2.84  ...  112.860001
# 7930  112.760002     0.7855  2711.739990       2.87  ...  112.790001
#
#       var8(t-1)      var1(t)  var2(t)  var3(t)    var4(t)      var5(t)  \
# 7926     0.7797  2641.250000     2.81     3.08  77.559998  1230.800049
# 7927     0.7808  2682.629883     2.84     3.12  75.680000  1225.400024
# 7928     0.7855  2711.739990     2.87     3.15  74.839996  1214.949951
# 7929     0.7825  2740.370117     2.84     3.14  71.250000  1231.150024
# 7930     0.7708  2723.060059     2.91     3.22  71.110001  1232.099976
#
#       var6(t)     var7(t)  var8(t)
# 7926   1.4136  112.489998   0.7808
# 7927   1.4061  112.760002   0.7855
# 7928   1.4104  112.860001   0.7825
# 7929   1.3910  112.790001   0.7708
# 7930   1.3891  113.089996   0.7713
#
# [5 rows x 32 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(reframed)
# Out:
# /home/abel/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning:
#
# Data with input dtype float32 were all converted to float64 by MinMaxScaler.

# %%
n_train_hours = int(len(scaled) * 0.7)

train = scaled[:n_train_hours, :]
test = scaled[n_train_hours:, :]

# %%
# train_t = scaler.inverse_transform(test)
# train_t[-1]

# %%
# split into input and outputs
train_X, train_y = train[:, :-8], train[:, -8:]
test_X, test_y = test[:, :-8], test[:, -8:]

# %%
train_X.shape
# Out:
# (5068, 24)

# %%
train_y.shape
# Out:
# (5068, 8)

# %%
train_X = train_X.reshape((train_X.shape[0], 3, 8))
test_X = test_X.reshape((test_X.shape[0], 3, 8))
#train_y = train_y.reshape((train_y.shape[0], 1, train_y.shape[1]))
#test_y = test_y.reshape((test_y.shape[0], 1, test_y.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (5068, 3, 8) (5068, 8) (2173, 3, 8) (2173, 8)

# %% [markdown]
# # Building the Model

# %%
import random
random.seed(12345)

# %%
#run the model

model = Sequential()
model.add(SimpleRNN(200, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True, 
                    kernel_initializer='orthogonal', bias_initializer='zeros', trainable= False))
model.add(SimpleRNN(200,return_sequences=True))
model.add(SimpleRNN(200))
model.add(Dense(8,activation='linear'))
model.compile(loss='mse', optimizer='adam')

# %%
wt1, wt2, wt3 = model.layers[1].get_weights()
from numpy.linalg import eigvals
lambdas = eigvals(wt2)
spec_rad = max(lambdas)
np.absolute(spec_rad)
alpha = 0.5
model.layers[1].set_weights([wt1,alpha*wt2,wt3])

# %%
from keras.callbacks import ModelCheckpoint

weight_path="{}_weights.hdf5".format('market_lstm_modelv3')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = False)
callbacks_list = [checkpoint]


model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_49 (SimpleRNN)    (None, 3, 200)            41800
# _________________________________________________________________
# simple_rnn_50 (SimpleRNN)    (None, 3, 200)            80200
# _________________________________________________________________
# simple_rnn_51 (SimpleRNN)    (None, 200)               80200
# _________________________________________________________________
# dense_17 (Dense)             (None, 8)                 1608
# =================================================================
# Total params: 203,808
# Trainable params: 162,008
# Non-trainable params: 41,800
# _________________________________________________________________

# %%
n_batch = 100
history = model.fit(train_X, train_y, epochs=50, batch_size=n_batch, validation_data=(test_X, test_y), callbacks = callbacks_list)
# Out:
# Train on 5068 samples, validate on 2173 samples
# Epoch 1/50
# 5068/5068 [==============================] - 2s 421us/step - loss: 0.0216 - val_loss: 0.0037
#
# Epoch 00001: val_loss improved from inf to 0.00371, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 2/50
# 5068/5068 [==============================] - 0s 85us/step - loss: 2.4887e-04 - val_loss: 0.0024
#
# Epoch 00002: val_loss improved from 0.00371 to 0.00245, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 3/50
# 5068/5068 [==============================] - 0s 92us/step - loss: 1.7556e-04 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00245 to 0.00183, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 4/50
# 5068/5068 [==============================] - 0s 83us/step - loss: 1.7090e-04 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00183 to 0.00177, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 5/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.7048e-04 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00177
# Epoch 6/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.6864e-04 - val_loss: 0.0016
#
# Epoch 00006: val_loss improved from 0.00177 to 0.00160, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 7/50
# 5068/5068 [==============================] - 0s 78us/step - loss: 1.6499e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00160 to 0.00148, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 8/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.5717e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00148 to 0.00145, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 9/50
# 5068/5068 [==============================] - 0s 81us/step - loss: 1.5601e-04 - val_loss: 0.0016
#
# Epoch 00009: val_loss did not improve from 0.00145
# Epoch 10/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.6067e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00145 to 0.00136, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 11/50
# 5068/5068 [==============================] - 0s 75us/step - loss: 1.5327e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00136 to 0.00128, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 12/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.5488e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss did not improve from 0.00128
# Epoch 13/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.6806e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00128 to 0.00107, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 14/50
# 5068/5068 [==============================] - 0s 76us/step - loss: 1.4618e-04 - val_loss: 0.0012
#
# Epoch 00014: val_loss did not improve from 0.00107
# Epoch 15/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.4681e-04 - val_loss: 8.3715e-04
#
# Epoch 00015: val_loss improved from 0.00107 to 0.00084, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 16/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.4931e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss did not improve from 0.00084
# Epoch 17/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.6033e-04 - val_loss: 7.7505e-04
#
# Epoch 00017: val_loss improved from 0.00084 to 0.00078, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 18/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.6243e-04 - val_loss: 9.0303e-04
#
# Epoch 00018: val_loss did not improve from 0.00078
# Epoch 19/50
# 5068/5068 [==============================] - 0s 78us/step - loss: 1.4901e-04 - val_loss: 7.6937e-04
#
# Epoch 00019: val_loss improved from 0.00078 to 0.00077, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 20/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.5431e-04 - val_loss: 0.0010
#
# Epoch 00020: val_loss did not improve from 0.00077
# Epoch 21/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.4080e-04 - val_loss: 6.8158e-04
#
# Epoch 00021: val_loss improved from 0.00077 to 0.00068, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 22/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.4977e-04 - val_loss: 7.3706e-04
#
# Epoch 00022: val_loss did not improve from 0.00068
# Epoch 23/50
# 5068/5068 [==============================] - 0s 69us/step - loss: 1.3968e-04 - val_loss: 8.9068e-04
#
# Epoch 00023: val_loss did not improve from 0.00068
# Epoch 24/50
# 5068/5068 [==============================] - 0s 75us/step - loss: 1.4795e-04 - val_loss: 7.6857e-04
#
# Epoch 00024: val_loss did not improve from 0.00068
# Epoch 25/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.3857e-04 - val_loss: 6.2988e-04
#
# Epoch 00025: val_loss improved from 0.00068 to 0.00063, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 26/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.4408e-04 - val_loss: 7.7503e-04
#
# Epoch 00026: val_loss did not improve from 0.00063
# Epoch 27/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.2682e-04 - val_loss: 5.5511e-04
#
# Epoch 00027: val_loss improved from 0.00063 to 0.00056, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 28/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.3754e-04 - val_loss: 7.6185e-04
#
# Epoch 00028: val_loss did not improve from 0.00056
# Epoch 29/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.5590e-04 - val_loss: 6.9233e-04
#
# Epoch 00029: val_loss did not improve from 0.00056
# Epoch 30/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.3340e-04 - val_loss: 5.3693e-04
#
# Epoch 00030: val_loss improved from 0.00056 to 0.00054, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 31/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2260e-04 - val_loss: 5.4236e-04
#
# Epoch 00031: val_loss did not improve from 0.00054
# Epoch 32/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.4364e-04 - val_loss: 6.0218e-04
#
# Epoch 00032: val_loss did not improve from 0.00054
# Epoch 33/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.4815e-04 - val_loss: 6.4459e-04
#
# Epoch 00033: val_loss did not improve from 0.00054
# Epoch 34/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.3005e-04 - val_loss: 5.7100e-04
#
# Epoch 00034: val_loss did not improve from 0.00054
# Epoch 35/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.4078e-04 - val_loss: 6.4441e-04
#
# Epoch 00035: val_loss did not improve from 0.00054
# Epoch 36/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2366e-04 - val_loss: 5.2236e-04
#
# Epoch 00036: val_loss improved from 0.00054 to 0.00052, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 37/50
# 5068/5068 [==============================] - 0s 74us/step - loss: 1.3061e-04 - val_loss: 4.7081e-04
#
# Epoch 00037: val_loss improved from 0.00052 to 0.00047, saving model to market_lstm_modelv3_weights.hdf5
# Epoch 38/50
# 5068/5068 [==============================] - 0s 75us/step - loss: 1.2886e-04 - val_loss: 5.7543e-04
#
# Epoch 00038: val_loss did not improve from 0.00047
# Epoch 39/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2224e-04 - val_loss: 6.5109e-04
#
# Epoch 00039: val_loss did not improve from 0.00047
# Epoch 40/50
# 5068/5068 [==============================] - 0s 75us/step - loss: 1.2159e-04 - val_loss: 5.4985e-04
#
# Epoch 00040: val_loss did not improve from 0.00047
# Epoch 41/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.3778e-04 - val_loss: 7.3057e-04
#
# Epoch 00041: val_loss did not improve from 0.00047
# Epoch 42/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2911e-04 - val_loss: 8.8982e-04
#
# Epoch 00042: val_loss did not improve from 0.00047
# Epoch 43/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.1773e-04 - val_loss: 7.3847e-04
#
# Epoch 00043: val_loss did not improve from 0.00047
# Epoch 44/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.1929e-04 - val_loss: 6.5781e-04
#
# Epoch 00044: val_loss did not improve from 0.00047
# Epoch 45/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.2782e-04 - val_loss: 8.3704e-04
#
# Epoch 00045: val_loss did not improve from 0.00047
# Epoch 46/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2615e-04 - val_loss: 6.0074e-04
#
# Epoch 00046: val_loss did not improve from 0.00047
# Epoch 47/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2373e-04 - val_loss: 6.0364e-04
#
# Epoch 00047: val_loss did not improve from 0.00047
# Epoch 48/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.1486e-04 - val_loss: 6.2199e-04
#
# Epoch 00048: val_loss did not improve from 0.00047
# Epoch 49/50
# 5068/5068 [==============================] - 0s 73us/step - loss: 1.0594e-04 - val_loss: 6.9926e-04
#
# Epoch 00049: val_loss did not improve from 0.00047
# Epoch 50/50
# 5068/5068 [==============================] - 0s 72us/step - loss: 1.2658e-04 - val_loss: 7.0872e-04
#
# Epoch 00050: val_loss did not improve from 0.00047

# %%
pyplot.plot(history.history['loss'], label='multi_train')
pyplot.plot(history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
yhat = model.predict(test_X)

# %%
test_y.shape
# Out:
# (2173, 8)

# %%
yhat.shape
# Out:
# (2173, 8)

# %%
#pyplot.plot(yhat[:,0][:,0], label='predict')
#pyplot.plot(test_y[:,0][:,0], label='true')
pyplot.plot(yhat[:,0], label='predict')
pyplot.plot(test_y[:,0], label='true')
pyplot.legend()
pyplot.show()

# %%
test_X.shape
# Out:
# (2173, 3, 8)

# %%
test_X.shape
# Out:
# (2173, 3, 8)

# %%
#reshape prediction
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1] * test_X.shape[2]))

#yhat.shape

#yhat = yhat.reshape((yhat.shape[0], yhat.shape[2]))

#test_X.shape

inv_yhat = concatenate((test_X[:, :], yhat), axis=1)

#inv_yhat.shape

inv_yhat = scaler.inverse_transform(inv_yhat)

#inv_yhat[:,-8:].shape

inv_yhat = inv_yhat[:,-8:]

#inv_yhat.shape

# %%
test_y.shape
# Out:
# (2173, 8)

# %%
inv_y = concatenate((test_X[:, :], test_y), axis=1)

#inv_y.shape

inv_y = scaler.inverse_transform(inv_y)

inv_y[:,-8:].shape

inv_y = inv_y[:,-8:]

#inv_y.shape

# %%
rmse = sqrt(mean_squared_error(test_y[:,0], yhat[:,0]))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.032

# %%
rmse = sqrt(mean_squared_error(inv_y[:,0], inv_yhat[:,0]))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 86.799

# %%
predictDates = data.tail(len(inv_y)).index
actual_chart = go.Scatter(x=predictDates, y=inv_y[:,3], name= 'Actual Price')
multi_predict_chart = go.Scatter(x=predictDates, y=inv_yhat[:,3], name= 'Multi Predict Price')
py.iplot([multi_predict_chart, actual_chart])
# Out:
# <div id="eecace14-7b08-4ca8-a95a-96b7c51fde55" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eecace14-7b08-4ca8-a95a-96b7c51fde55", [{"type": "scatter", "x": [20100322, 20100323, 20100324, 20100325, 20100326, 20100329, 20100330, 20100331, 20100401, 20100405, 20100406, 20100407, 20100408, 20100409, 20100412, 20100413, 20100414, 20100415, 20100416, 20100419, 20100420, 20100421, 20100422, 20100423, 20100426, 20100427, 20100428, 20100429, 20100430, 20100503, 20100504, 20100505, 20100506, 20100507, 20100510, 20100511, 20100512, 20100513, 20100514, 20100517, 20100518, 20100519, 20100520, 20100521, 20100524, 20100525, 20100526, 20100527, 20100528, 20100601, 20100602, 20100603, 20100604, 20100607, 20100608, 20100609, 20100610, 20100611, 20100614, 20100615, 20100616, 20100617, 20100618, 20100621, 20100622, 20100623, 20100624, 20100625, 20100628, 20100629, 20100630, 20100701, 20100702, 20100706, 20100707, 20100708, 20100709, 20100712, 20100713, 20100714, 20100715, 20100716, 20100719, 20100720, 20100721, 20100722, 20100723, 20100726, 20100727, 20100728, 20100729, 20100730, 20100802, 20100803, 20100804, 20100805, 20100806, 20100809, 20100810, 20100811, 20100812, 20100813, 20100816, 20100817, 20100818, 20100819, 20100820, 20100823, 20100824, 20100825, 20100826, 20100827, 20100830, 20100831, 20100901, 20100902, 20100903, 20100907, 20100908, 20100909, 20100910, 20100913, 20100914, 20100915, 20100916, 20100917, 20100920, 20100921, 20100922, 20100923, 20100924, 20100927, 20100928, 20100929, 20100930, 20101001, 20101004, 20101005, 20101006, 20101007, 20101008, 20101011, 20101012, 20101013, 20101014, 20101015, 20101018, 20101019, 20101020, 20101021, 20101022, 20101025, 20101026, 20101027, 20101028, 20101029, 20101101, 20101102, 20101103, 20101104, 20101105, 20101108, 20101109, 20101110, 20101111, 20101112, 20101115, 20101116, 20101117, 20101118, 20101119, 20101122, 20101123, 20101124, 20101126, 20101129, 20101130, 20101201, 20101202, 20101203, 20101206, 20101207, 20101208, 20101209, 20101210, 20101213, 20101214, 20101215, 20101216, 20101217, 20101220, 20101221, 20101222, 20101223, 20101227, 20101228, 20101229, 20101230, 20101231, 20110103, 20110104, 20110105, 20110106, 20110107, 20110110, 20110111, 20110112, 20110113, 20110114, 20110118, 20110119, 20110120, 20110121, 20110124, 20110125, 20110126, 20110127, 20110128, 20110131, 20110201, 20110202, 20110203, 20110204, 20110207, 20110208, 20110209, 20110210, 20110211, 20110214, 20110215, 20110216, 20110217, 20110218, 20110222, 20110223, 20110224, 20110225, 20110228, 20110301, 20110302, 20110303, 20110304, 20110307, 20110308, 20110309, 20110310, 20110311, 20110314, 20110315, 20110316, 20110317, 20110318, 20110321, 20110322, 20110323, 20110324, 20110325, 20110328, 20110329, 20110330, 20110331, 20110401, 20110404, 20110405, 20110406, 20110407, 20110408, 20110411, 20110412, 20110413, 20110414, 20110415, 20110418, 20110419, 20110420, 20110421, 20110425, 20110426, 20110427, 20110428, 20110429, 20110502, 20110503, 20110504, 20110505, 20110506, 20110509, 20110510, 20110511, 20110512, 20110513, 20110516, 20110517, 20110518, 20110519, 20110520, 20110523, 20110524, 20110525, 20110526, 20110527, 20110531, 20110601, 20110602, 20110603, 20110606, 20110607, 20110608, 20110609, 20110610, 20110613, 20110614, 20110615, 20110616, 20110617, 20110620, 20110621, 20110622, 20110623, 20110624, 20110627, 20110628, 20110629, 20110630, 20110701, 20110705, 20110706, 20110707, 20110708, 20110711, 20110712, 20110713, 20110714, 20110715, 20110718, 20110719, 20110720, 20110721, 20110722, 20110725, 20110726, 20110727, 20110728, 20110729, 20110801, 20110802, 20110803, 20110804, 20110805, 20110808, 20110809, 20110810, 20110811, 20110812, 20110815, 20110816, 20110817, 20110818, 20110819, 20110822, 20110823, 20110824, 20110825, 20110826, 20110829,  ...
