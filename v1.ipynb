# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv(filepath_or_buffer="./Data/clean_data.csv", index_col="date")

# %%
data.head()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU  spindx GOLDPMGBD228NLBM  exalus  \
# date
# 19870520       8.05        8.92        18.63  278.21          475.250  1.3820
# 19870521       8.06        8.87        18.45  280.17          469.100  1.3864
# 19870522       7.97        8.78        18.55  282.16          466.500  1.3883
# 19870526       7.79        8.55        18.63  289.11          449.000  1.4029
# 19870527       7.84        8.60        18.60  288.73          449.500  1.3988
#
#           exjpus  exukus
# date
# 19870520  139.78  0.5942
# 19870521  140.45  0.5956
# 19870522  140.60  0.5977
# 19870526  143.30  0.6120
# 19870527  143.52  0.6200

# %%
data.tail()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU   spindx GOLDPMGBD228NLBM  \
# date
# 20181029       2.81        3.08        77.56  2641.25          1230.80
# 20181030       2.84        3.12        75.68  2682.63          1225.40
# 20181031       2.87        3.15        74.84  2711.74          1214.95
# 20181101       2.84        3.14        71.25  2740.37          1231.15
# 20181102       2.91        3.22        71.11  2723.06          1232.10
#
#           exalus  exjpus  exukus
# date
# 20181029  1.4136  112.49  0.7808
# 20181030  1.4061  112.76  0.7855
# 20181031  1.4104  112.86  0.7825
# 20181101  1.3910  112.79  0.7708
# 20181102  1.3891  113.09  0.7713

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7931 non-null object
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7931 non-null object
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 557.6+ KB

# %%
#data.DCOILBRENTEU.to_numericd
#data.GOLDPMGBD228NLBM = data.GOLDPMGBD228NLBM.astype(dtype = np.float64)
#data['GOLDPMGBD228NLBM'][0]
data = data.apply(pd.to_numeric, errors = "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7858 non-null float64
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7734 non-null float64
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(8)
# memory usage: 557.6 KB

# %%
btc_trace = go.Scatter(x=data.index, y=data['exukus'], name= 'exu')
py.iplot([btc_trace])
# Out:
# <div id="871eea1b-f011-40ac-b43d-3e3c3a85c2ea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("871eea1b-f011-40ac-b43d-3e3c3a85c2ea", [{"name": "exu", "x": [19870520, 19870521, 19870522, 19870526, 19870527, 19870528, 19870529, 19870601, 19870602, 19870603, 19870604, 19870605, 19870608, 19870609, 19870610, 19870611, 19870612, 19870615, 19870616, 19870617, 19870618, 19870619, 19870622, 19870623, 19870624, 19870625, 19870626, 19870629, 19870630, 19870701,
# %%
data['exukus'].replace(0, np.nan, inplace=True)
data['exukus'].fillna(method='ffill', inplace=True)

# %%
#reshaping prediction value into value range -1 to 1
from sklearn.preprocessing import MinMaxScaler

# %%
values = data['exukus'].values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
values
# Out:
# array([[0.5942],
#        [0.5956],
#        [0.5977],
#        ...,
#        [0.7825],
#        [0.7708],
#        [0.7713]], dtype=float32)

# %%
scaled
# Out:
# array([[0.34262943],
#        [0.34661353],
#        [0.3525896 ],
#        ...,
#        [0.8784859 ],
#        [0.8451905 ],
#        [0.8466134 ]], dtype=float32)

# %%
#split dataset into train and test, 70% train 30% test

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print(len(train), len(test))
# Out:
# 5551 2380

# %%
#function that convert the dataset to be 3d
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 3 #use 3 previous days to predict the next day
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# Out:
# 5548
# 2377

# %%
trainX
# Out:
# array([[0.34262943, 0.34661353, 0.3525896 ],
#        [0.34661353, 0.3525896 , 0.39328384],
#        [0.3525896 , 0.39328384, 0.41605008],
#        ...,
#        [0.52105856, 0.51052916, 0.4874786 ],
#        [0.51052916, 0.4874786 , 0.46784282],
#        [0.4874786 , 0.46784282, 0.45702899]], dtype=float32)

# %%
trainY
# Out:
# array([0.39328384, 0.41605008, 0.40239036, ..., 0.46784282, 0.45702899,
#        0.44223094], dtype=float32)

# %%
#reshaping data into 3-D
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX
# Out:
# array([[[0.34262943, 0.34661353, 0.3525896 ]],
#
#        [[0.34661353, 0.3525896 , 0.39328384]],
#
#        [[0.3525896 , 0.39328384, 0.41605008]],
#
#        ...,
#
#        [[0.52105856, 0.51052916, 0.4874786 ]],
#
#        [[0.51052916, 0.4874786 , 0.46784282]],
#
#        [[0.4874786 , 0.46784282, 0.45702899]]], dtype=float32)

# %%
#run the model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=50, batch_size=100, validation_data=(testX, testY), verbose=1, shuffle=False)
# Out:
# Train on 5548 samples, validate on 2377 samples
# Epoch 1/50
# 5548/5548 [==============================] - 2s 281us/step - loss: 0.1701 - val_loss: 0.0426
# Epoch 2/50
# 5548/5548 [==============================] - 0s 72us/step - loss: 0.0523 - val_loss: 0.0565
# Epoch 3/50
# 5548/5548 [==============================] - 0s 73us/step - loss: 0.0292 - val_loss: 0.0574
# Epoch 4/50
# 5548/5548 [==============================] - 0s 71us/step - loss: 0.0146 - val_loss: 0.0543
# Epoch 5/50
# 5548/5548 [==============================] - 0s 74us/step - loss: 0.0135 - val_loss: 0.0200
# Epoch 6/50
# 5548/5548 [==============================] - 0s 73us/step - loss: 0.0121 - val_loss: 0.0184
# Epoch 7/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0123 - val_loss: 0.0172
# Epoch 8/50
# 5548/5548 [==============================] - 0s 70us/step - loss: 0.0119 - val_loss: 0.0170
# Epoch 9/50
# 5548/5548 [==============================] - 0s 70us/step - loss: 0.0121 - val_loss: 0.0178
# Epoch 10/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0120 - val_loss: 0.0174
# Epoch 11/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0118 - val_loss: 0.0170
# Epoch 12/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0118 - val_loss: 0.0173
# Epoch 13/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0117 - val_loss: 0.0171
# Epoch 14/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0117 - val_loss: 0.0175
# Epoch 15/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0114 - val_loss: 0.0167
# Epoch 16/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0112 - val_loss: 0.0160
# Epoch 17/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0109 - val_loss: 0.0150
# Epoch 18/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0109 - val_loss: 0.0148
# Epoch 19/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0108 - val_loss: 0.0142
# Epoch 20/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0106 - val_loss: 0.0140
# Epoch 21/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0104 - val_loss: 0.0133
# Epoch 22/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0103 - val_loss: 0.0126
# Epoch 23/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0102 - val_loss: 0.0121
# Epoch 24/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0101 - val_loss: 0.0117
# Epoch 25/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0099 - val_loss: 0.0111
# Epoch 26/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0098 - val_loss: 0.0108
# Epoch 27/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0098 - val_loss: 0.0105
# Epoch 28/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0096 - val_loss: 0.0104
# Epoch 29/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0096 - val_loss: 0.0102
# Epoch 30/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0095 - val_loss: 0.0102
# Epoch 31/50
# 5548/5548 [==============================] - 0s 70us/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 32/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 33/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 34/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0092 - val_loss: 0.0100
# Epoch 35/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0092 - val_loss: 0.0100
# Epoch 36/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0092 - val_loss: 0.0102
# Epoch 37/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 38/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 39/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 40/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 41/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 42/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0090 - val_loss: 0.0105
# Epoch 43/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0090 - val_loss: 0.0112
# Epoch 44/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0090 - val_loss: 0.0117
# Epoch 45/50
# 5548/5548 [==============================] - 0s 69us/step - loss: 0.0090 - val_loss: 0.0122
# Epoch 46/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0090 - val_loss: 0.0124
# Epoch 47/50
# 5548/5548 [==============================] - 0s 70us/step - loss: 0.0090 - val_loss: 0.0128
# Epoch 48/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0090 - val_loss: 0.0127
# Epoch 49/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0091 - val_loss: 0.0143
# Epoch 50/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0092 - val_loss: 0.0146

# %%
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
#inverse y back to values
yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0
, 20100510, 20100511, 20100512, 20100513, 20100514, 20100517, 20100518, 20100519, 20100520, 20100521, 20100524, 20100525, 20100526, 20100527, 20100528, 20100601, 20100602, 20100603, 20100604, 20100607, 20100608, 20100609, 20100610, 20100611, 20100614, 20100615, 20100616, 20100617, 20100618, 20100621, 20100622, 20100623, 20100624, 20100625, 20100628, 20100629, 20100630, 20100701, 20100702, 20100706, 20100707, 20100708, 20100709, 20100712, 20100713, 20100714, 20100715, 20100716, 20100719, 20100720, 20100721, 20100722, 20100723, 20100726, 20100727, 20100728, 20100729, 20100730, 20100802, 20100803, 20100804, 20100805, 20100806, 20100809, 20100810, 20100811, 20100812, 20100813, 20100816, 20100817, 20100818, 20100819, 20100820, 20100823, 20100824, 20100825, 20100826, 20100827, 20100830, 20100831, 20100901, 20100902, 20100903, 20100907, 20100908, 20100909, 20100910, 20100913, 20100914, 20100915, 20100916, 20100917, 20100920, 20100921, 20100922, 20100923, 20100924, 20100927, 20100928, 20100929, 20100930, 20101001, 20101004, 20101005, 20101006, 20101007, 20101008, 20101011, 20101012, 20101013, 20101014, 20101015, 20101018, 20101019, 20101020, 20101021, 20101022, 20101025, 20101026, 20101027, 20101028, 20101029, 20101101, 20101102, 20101103, 20101104, 2010 ...

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.1, vmin=0)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
data.columns
#values = data[['exukus'] + ['Volume (BTC)'] + ['Volume (Currency)']].values
#values = values.astype('float32')
# Out:
# Index(['TCMNOM_Y2', 'TCMNOM_Y10', 'DCOILBRENTEU', 'spindx', 'GOLDPMGBD228NLBM',
#        'exalus', 'exjpus', 'exukus'],
#       dtype='object')

# %%
values = data[['exukus'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10']].values
number_of_variables = 3
#values = data[['spindx'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10'] + ['DCOILBRENTEU'] + ['GOLDPMGBD228NLBM'] + ['exalus'] + ['exjpus'] + ['exukus']].values
values = values.astype('float32')

# %%
#normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#convert data to become supervised 
look_back = 1
time_steps = 2
reframed = series_to_supervised(scaled, look_back, time_steps)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)  var1(t+1)  \
# 1   0.342629   0.808402   0.852144  0.346614  0.809426  0.846501   0.352590
# 2   0.346614   0.809426   0.846501  0.352590  0.800205  0.836343   0.393284
# 3   0.352590   0.800205   0.836343  0.393284  0.781762  0.810384   0.416050
# 4   0.393284   0.781762   0.810384  0.416050  0.786885  0.816027   0.402390
# 5   0.416050   0.786885   0.816027  0.402390  0.783811  0.811512   0.398122
#
#    var2(t+1)  var3(t+1)
# 1   0.800205   0.836343
# 2   0.781762   0.810384
# 3   0.786885   0.816027
# 4   0.783811   0.811512
# 5   0.771516   0.803612

# %%
#reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
#reframed.drop(reframed.columns[-7:], axis=1, inplace=True)
#reframed.drop(reframed.columns[-1 * number_of_variables + 1:], axis=1, inplace=True)
reframed.drop(reframed.columns[-2:], axis=1, inplace=True)
print(reframed.head())
#splitting data 
values = reframed.values
n_train_hours = int(len(values) * 0.7)
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)  var1(t+1)
# 1   0.342629   0.808402   0.852144  0.346614  0.809426  0.846501   0.352590
# 2   0.346614   0.809426   0.846501  0.352590  0.800205  0.836343   0.393284
# 3   0.352590   0.800205   0.836343  0.393284  0.781762  0.810384   0.416050
# 4   0.393284   0.781762   0.810384  0.416050  0.786885  0.816027   0.402390
# 5   0.416050   0.786885   0.816027  0.402390  0.783811  0.811512   0.398122

# %%
# split into input and outputs
# train_X, train_y = train[:, :-1], train[:, -1]
# test_X, test_y = test[:, :-1], test[:, -1]


target = -1 * number_of_variables
look_back = 1
number_of_variables = 3
train_X, train_y = train[:, :(look_back * number_of_variables)], train[:, -1]
test_X, test_y = test[:, :(look_back * number_of_variables) ], test[:, -1]

# %%
train_X
# Out:
# array([[0.34262943, 0.80840164, 0.8521445 ],
#        [0.34661353, 0.80942625, 0.8465011 ],
#        [0.3525896 , 0.8002049 , 0.83634305],
#        ...,
#        [0.4874786 , 0.07684426, 0.21218963],
#        [0.46784282, 0.0727459 , 0.20541762],
#        [0.45702899, 0.07479508, 0.22347628]], dtype=float32)

# %%
train_y
# Out:
# array([0.3525896 , 0.39328384, 0.41605008, ..., 0.45702899, 0.44223094,
#        0.43710864], dtype=float32)

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (5550, 1, 3) (5550,) (2379, 1, 3) (2379,)

# %%
multi_model = Sequential()
multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
multi_model.add(Dense(1))
multi_model.compile(loss='mae', optimizer='adam')
multi_history = multi_model.fit(train_X, train_y, epochs=50, batch_size=100, validation_data=(test_X, test_y), verbose=1, shuffle=False)
# Out:
# Train on 5550 samples, validate on 2379 samples
# Epoch 1/50
# 5550/5550 [==============================] - 2s 346us/step - loss: 0.2007 - val_loss: 0.1951
# Epoch 2/50
# 5550/5550 [==============================] - 0s 81us/step - loss: 0.1467 - val_loss: 0.1617
# Epoch 3/50
# 5550/5550 [==============================] - 0s 80us/step - loss: 0.1327 - val_loss: 0.1243
# Epoch 4/50
# 5550/5550 [==============================] - 0s 80us/step - loss: 0.1182 - val_loss: 0.0993
# Epoch 5/50
# 5550/5550 [==============================] - 0s 79us/step - loss: 0.1053 - val_loss: 0.0746
# Epoch 6/50
# 5550/5550 [==============================] - 0s 74us/step - loss: 0.0917 - val_loss: 0.0542
# Epoch 7/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0680 - val_loss: 0.0502
# Epoch 8/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0378 - val_loss: 0.0732
# Epoch 9/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0324 - val_loss: 0.0457
# Epoch 10/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0173 - val_loss: 0.0593
# Epoch 11/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0173 - val_loss: 0.0367
# Epoch 12/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 13/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0123 - val_loss: 0.0134
# Epoch 14/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0125 - val_loss: 0.0130
# Epoch 15/50
# 5550/5550 [==============================] - 0s 66us/step - loss: 0.0126 - val_loss: 0.0127
# Epoch 16/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0125 - val_loss: 0.0128
# Epoch 17/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0128 - val_loss: 0.0129
# Epoch 18/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0129 - val_loss: 0.0133
# Epoch 19/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0130 - val_loss: 0.0137
# Epoch 20/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0132 - val_loss: 0.0143
# Epoch 21/50
# 5550/5550 [==============================] - 0s 71us/step - loss: 0.0133 - val_loss: 0.0142
# Epoch 22/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 23/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0134 - val_loss: 0.0146
# Epoch 24/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0135 - val_loss: 0.0148
# Epoch 25/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0134 - val_loss: 0.0152
# Epoch 26/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0136 - val_loss: 0.0150
# Epoch 27/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0136 - val_loss: 0.0151
# Epoch 28/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0151
# Epoch 29/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0160
# Epoch 30/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0137 - val_loss: 0.0163
# Epoch 31/50
# 5550/5550 [==============================] - 0s 69us/step - loss: 0.0138 - val_loss: 0.0168
# Epoch 32/50
# 5550/5550 [==============================] - 0s 77us/step - loss: 0.0139 - val_loss: 0.0170
# Epoch 33/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0138 - val_loss: 0.0170
# Epoch 34/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0138 - val_loss: 0.0172
# Epoch 35/50
# 5550/5550 [==============================] - 0s 67us/step - loss: 0.0138 - val_loss: 0.0171
# Epoch 36/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0177
# Epoch 37/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0138 - val_loss: 0.0174
# Epoch 38/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0180
# Epoch 39/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0179
# Epoch 40/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0177
# Epoch 41/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0137 - val_loss: 0.0176
# Epoch 42/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0136 - val_loss: 0.0173
# Epoch 43/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0135 - val_loss: 0.0172
# Epoch 44/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0135 - val_loss: 0.0177
# Epoch 45/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0135 - val_loss: 0.0175
# Epoch 46/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0134 - val_loss: 0.0180
# Epoch 47/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0135 - val_loss: 0.0178
# Epoch 48/50
# 5550/5550 [==============================] - 0s 72us/step - loss: 0.0134 - val_loss: 0.0181
# Epoch 49/50
# 5550/5550 [==============================] - 0s 66us/step - loss: 0.0134 - val_loss: 0.0179
# Epoch 50/50
# 5550/5550 [==============================] - 0s 68us/step - loss: 0.0134 - val_loss: 0.0183

# %%
#plot result 
pyplot.plot(multi_history.history['loss'], label='multi_train')
pyplot.plot(multi_history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
#plot prediction
yhat = multi_model.predict(test_X)
pyplot.plot(yhat, label='predict')
pyplot.plot(test_y, label='true')
pyplot.legend()
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
#test_X.shape[2]

# %%
test_X
# Out:
# array([[0.44223094, 0.07786885, 0.23476298],
#        [0.43710864, 0.0819672 , 0.24040632],
#        [0.42287982, 0.0819672 , 0.26410836],
#        ...,
#        [0.87364817, 0.27151638, 0.19300224],
#        [0.8870232 , 0.27459013, 0.1975169 ],
#        [0.8784859 , 0.27766392, 0.20090295]], dtype=float32)

# %%
#test_X[:, 1:]
yhat
# Out:
# array([[0.43053925],
#        [0.42558804],
#        [0.4116052 ],
#        ...,
#        [0.84451187],
#        [0.85727084],
#        [0.8491852 ]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)

# %%
inv_yhat
# Out:
# array([[0.43053925, 0.07786885, 0.23476298],
#        [0.42558804, 0.0819672 , 0.24040632],
#        [0.4116052 , 0.0819672 , 0.26410836],
#        ...,
#        [0.84451187, 0.27151638, 0.19300224],
#        [0.85727084, 0.27459013, 0.1975169 ],
#        [0.8491852 , 0.27766392, 0.20090295]], dtype=float32)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
#inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# %%
inv_yhat
# Out:
# array([0.6934572 , 0.69284576, 0.6911192 , ..., 0.74457544, 0.7461508 ,
#        0.7451524 ], dtype=float32)

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)

# %%
inv_y
# Out:
# array([[0.42287982, 0.07786885, 0.23476298],
#        [0.43511653, 0.0819672 , 0.24040632],
#        [0.4126351 , 0.0819672 , 0.26410836],
#        ...,
#        [0.8784859 , 0.27151638, 0.19300224],
#        [0.8451905 , 0.27459013, 0.1975169 ],
#        [0.8466134 , 0.27766392, 0.20090295]], dtype=float32)

# %%
inv_y = scaler.inverse_transform(inv_y)

# %%
inv_y
# Out:
# array([[0.6224    , 0.91999996, 3.45      ],
#        [0.6267    , 0.9599999 , 3.5       ],
#        [0.6188    , 0.9599999 , 3.7100003 ],
#        ...,
#        [0.78249997, 2.8100002 , 3.08      ],
#        [0.7708    , 2.84      , 3.12      ],
#        [0.77129996, 2.8700001 , 3.15      ]], dtype=float32)

# %%
inv_y = inv_y[:,0]

# %%
inv_y
# Out:
# array([0.6224    , 0.6267    , 0.6188    , ..., 0.78249997, 0.7708    ,
#        0.77129996], dtype=float32)

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.057

# %%
actual_chart = go.Scatter(x=predictDates, y=inv_y, name= 'Actual Price')
multi_predict_chart = go.Scatter(x=predictDates, y=inv_yhat, name= 'Multi Predict Price')
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
py.iplot([predict_chart, multi_predict_chart, actual_chart])
# Out:
# <div id="84a73050-6927-4293-aa67-f25924dd4c5b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("84a73050-6927-4293-aa67-f25924dd4c5b", [{"name": "Predict Price", "x": [20090529, 20090601, 20090602, 20090603, 20090604, 20090605, 20090608, 20090609, 20090610, 20090611, 20090612, 20090615, 20090616, 20090617, 20090618, 20090619, 20090622, 20090623, 20090624, 20090625, 20090626, 20090629, 20090630, 20090701, 20090702, 20090706, 20090707, 20090708, 20090709, 20090710, 20090713, 20090714, 20090715, 20090716, 20090717, 20090720, 20090721, 20090722, 20090723, 20090724, 20090727, 20090728, 20090729, 20090730, 20090731, 20090803, 20090804, 20090805, 20090806, 20090807, 20090810, 20090811, 20090812, 20090813, 20090814, 20090817, 20090818, 20090819, 20090820, 20090821, 20