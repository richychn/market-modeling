# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras import backend as K
from keras.layers import Dense, LSTM, TimeDistributed
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv(filepath_or_buffer="./Data/clean_data.csv", index_col="date")

# %%
data.head()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU  spindx GOLDPMGBD228NLBM  exalus  \
# date
# 19870520       8.05        8.92        18.63  278.21          475.250  1.3820
# 19870521       8.06        8.87        18.45  280.17          469.100  1.3864
# 19870522       7.97        8.78        18.55  282.16          466.500  1.3883
# 19870526       7.79        8.55        18.63  289.11          449.000  1.4029
# 19870527       7.84        8.60        18.60  288.73          449.500  1.3988
#
#           exjpus  exukus
# date
# 19870520  139.78  0.5942
# 19870521  140.45  0.5956
# 19870522  140.60  0.5977
# 19870526  143.30  0.6120
# 19870527  143.52  0.6200

# %%
data.tail()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU   spindx GOLDPMGBD228NLBM  \
# date
# 20181029       2.81        3.08        77.56  2641.25          1230.80
# 20181030       2.84        3.12        75.68  2682.63          1225.40
# 20181031       2.87        3.15        74.84  2711.74          1214.95
# 20181101       2.84        3.14        71.25  2740.37          1231.15
# 20181102       2.91        3.22        71.11  2723.06          1232.10
#
#           exalus  exjpus  exukus
# date
# 20181029  1.4136  112.49  0.7808
# 20181030  1.4061  112.76  0.7855
# 20181031  1.4104  112.86  0.7825
# 20181101  1.3910  112.79  0.7708
# 20181102  1.3891  113.09  0.7713

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7931 non-null object
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7931 non-null object
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 557.6+ KB

# %%
data = data.apply(pd.to_numeric, errors = "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7858 non-null float64
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7734 non-null float64
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(8)
# memory usage: 557.6 KB

# %%
data['spindx'].replace(0, np.nan, inplace=True)
data['spindx'].fillna(method='ffill', inplace=True)

# %%
#reshaping prediction value into value range -1 to 1
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # MULTIVARIATE PREDICTION (WITH LOOKBACK AND TIMESTEPS)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
data.columns
# Out:
# Index(['TCMNOM_Y2', 'TCMNOM_Y10', 'DCOILBRENTEU', 'spindx', 'GOLDPMGBD228NLBM',
#        'exalus', 'exjpus', 'exukus'],
#       dtype='object')

# %%
number_of_variables = 8
values = data[['spindx'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10'] + ['DCOILBRENTEU'] + ['GOLDPMGBD228NLBM'] + ['exalus'] + ['exjpus'] + ['exukus']].values
values = values.astype('float32')

# %%
values
# Out:
# array([[2.78210e+02, 8.05000e+00, 8.92000e+00, ..., 1.38200e+00,
#         1.39780e+02, 5.94200e-01],
#        [2.80170e+02, 8.06000e+00, 8.87000e+00, ..., 1.38640e+00,
#         1.40450e+02, 5.95600e-01],
#        [2.82160e+02, 7.97000e+00, 8.78000e+00, ..., 1.38830e+00,
#         1.40600e+02, 5.97700e-01],
#        ...,
#        [2.71174e+03, 2.87000e+00, 3.15000e+00, ..., 1.41040e+00,
#         1.12860e+02, 7.82500e-01],
#        [2.74037e+03, 2.84000e+00, 3.14000e+00, ..., 1.39100e+00,
#         1.12790e+02, 7.70800e-01],
#        [2.72306e+03, 2.91000e+00, 3.22000e+00, ..., 1.38910e+00,
#         1.13090e+02, 7.71300e-01]], dtype=float32)

# %%
look_back = 10
time_steps = 1
series_to_supervised(values, look_back, time_steps)
reframed = series_to_supervised(values, look_back, time_steps)
reframed.tail()
# Out:
#        var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)   var5(t-10)  \
# 7926  2750.790039        2.85        3.16   80.910004  1229.949951
# 7927  2809.919922        2.87        3.16   80.529999  1230.699951
# 7928  2809.209961        2.89        3.19   79.910004  1229.050049
# 7929  2768.780029        2.87        3.17   80.300003  1223.000000
# 7930  2767.780029        2.92        3.20   80.379997  1227.849976
#
#       var6(t-10)  var7(t-10)  var8(t-10)    var1(t-9)  var2(t-9)  ...  \
# 7926      1.4002  111.820000      0.7594  2809.919922       2.87  ...
# 7927      1.4006  112.160004      0.7570  2809.209961       2.89  ...
# 7928      1.4025  112.209999      0.7612  2768.780029       2.87  ...
# 7929      1.4049  112.110001      0.7656  2767.780029       2.92  ...
# 7930      1.4021  112.519997      0.7666  2755.879883       2.92  ...
#
#        var7(t-1)  var8(t-1)      var1(t)  var2(t)  var3(t)    var4(t)  \
# 7926  111.650002     0.7797  2641.250000     2.81     3.08  77.559998
# 7927  112.489998     0.7808  2682.629883     2.84     3.12  75.680000
# 7928  112.760002     0.7855  2711.739990     2.87     3.15  74.839996
# 7929  112.860001     0.7825  2740.370117     2.84     3.14  71.250000
# 7930  112.790001     0.7708  2723.060059     2.91     3.22  71.110001
#
#           var5(t)  var6(t)     var7(t)  var8(t)
# 7926  1230.800049   1.4136  112.489998   0.7808
# 7927  1225.400024   1.4061  112.760002   0.7855
# 7928  1214.949951   1.4104  112.860001   0.7825
# 7929  1231.150024   1.3910  112.790001   0.7708
# 7930  1232.099976   1.3891  113.089996   0.7713
#
# [5 rows x 88 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(reframed)
# Out:
# /home/tjiang20/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning:
#
# Data with input dtype float32 were all converted to float64 by MinMaxScaler.

# %%
n_train_hours = int(len(scaled) * 0.7)

train = scaled[:n_train_hours, :]
test = scaled[n_train_hours:, :]

# %%
# train_t = scaler.inverse_transform(test)
# train_t[-1]

# %%
# split into input and outputs
train_X, train_y = train[:, :-8], train[:, -8:]
test_X, test_y = test[:, :-8], test[:, -8:]

# %%
train_X.shape
# Out:
# (4412, 80)

# %%
train_y.shape
# Out:
# (4412, 8)

# %%
train_X = train_X.reshape((train_X.shape[0], 10, 8))
test_X = test_X.reshape((test_X.shape[0], 10, 8))
#train_y = train_y.reshape((train_y.shape[0], 1, train_y.shape[1]))
#test_y = test_y.reshape((test_y.shape[0], 1, test_y.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (4412, 10, 8) (4412, 8) (1892, 10, 8) (1892, 8)

# %% [markdown]
# # Building the Model

# %%
def stock_loss(y_true, y_pred):
    alpha = 100.
    loss = K.switch(K.less(y_true * y_pred, 0), \
        alpha*y_pred**2 - K.sign(y_true)*y_pred + K.abs(y_true), \
        K.abs(y_true - y_pred)
        )
    return K.std(loss, axis=-1)

# %%
model = Sequential()

model.add(LSTM(
    input_shape=(train_X.shape[1],train_X.shape[2]),
    return_sequences=True, units=100))
model.add(Dropout(0.2))
#model.add(LSTM(units=100, return_sequences=True))
#model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(
    250,
    return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(8 , activation='linear'))

from keras.callbacks import ModelCheckpoint

weight_path="{}_weights.hdf5".format('market_lstm_modelv4')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = False)
callbacks_list = [checkpoint]

opt = Nadam(lr=0.002)
#model.compile(optimizer='adam', loss='mean_squared_error')
model.compile(optimizer='adam', loss=stock_loss)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 10, 100)           43600
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 250)               351000
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 2008
# =================================================================
# Total params: 396,608
# Trainable params: 396,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
n_batch = 125
history = model.fit(train_X, train_y, epochs=50, batch_size=n_batch, validation_data=(test_X, test_y), callbacks = callbacks_list)
# Out:
# Train on 4412 samples, validate on 1892 samples
# Epoch 1/50
# 4412/4412 [==============================] - 4s 795us/step - loss: 0.1062 - val_loss: 0.1690
#
# Epoch 00001: val_loss improved from inf to 0.16903, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 2/50
# 4412/4412 [==============================] - 2s 461us/step - loss: 0.0326 - val_loss: 0.1190
#
# Epoch 00002: val_loss improved from 0.16903 to 0.11901, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 3/50
# 4412/4412 [==============================] - 2s 446us/step - loss: 0.0190 - val_loss: 0.0768
#
# Epoch 00003: val_loss improved from 0.11901 to 0.07683, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 4/50
# 4412/4412 [==============================] - 2s 444us/step - loss: 0.0144 - val_loss: 0.0656
#
# Epoch 00004: val_loss improved from 0.07683 to 0.06560, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 5/50
# 4412/4412 [==============================] - 2s 451us/step - loss: 0.0121 - val_loss: 0.0510
#
# Epoch 00005: val_loss improved from 0.06560 to 0.05104, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 6/50
# 4412/4412 [==============================] - 2s 447us/step - loss: 0.0112 - val_loss: 0.0456
#
# Epoch 00006: val_loss improved from 0.05104 to 0.04562, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 7/50
# 4412/4412 [==============================] - 2s 446us/step - loss: 0.0113 - val_loss: 0.0400
#
# Epoch 00007: val_loss improved from 0.04562 to 0.03996, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 8/50
# 4412/4412 [==============================] - 2s 451us/step - loss: 0.0107 - val_loss: 0.0368
#
# Epoch 00008: val_loss improved from 0.03996 to 0.03684, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 9/50
# 4412/4412 [==============================] - 2s 442us/step - loss: 0.0101 - val_loss: 0.0259
#
# Epoch 00009: val_loss improved from 0.03684 to 0.02590, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 10/50
# 4412/4412 [==============================] - 2s 456us/step - loss: 0.0114 - val_loss: 0.0206
#
# Epoch 00010: val_loss improved from 0.02590 to 0.02058, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 11/50
# 4412/4412 [==============================] - 2s 447us/step - loss: 0.0101 - val_loss: 0.0281
#
# Epoch 00011: val_loss did not improve from 0.02058
# Epoch 12/50
# 4412/4412 [==============================] - 2s 449us/step - loss: 0.0099 - val_loss: 0.0199
#
# Epoch 00012: val_loss improved from 0.02058 to 0.01985, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 13/50
# 4412/4412 [==============================] - 2s 446us/step - loss: 0.0094 - val_loss: 0.0226
#
# Epoch 00013: val_loss did not improve from 0.01985
# Epoch 14/50
# 4412/4412 [==============================] - 2s 441us/step - loss: 0.0094 - val_loss: 0.0515
#
# Epoch 00014: val_loss did not improve from 0.01985
# Epoch 15/50
# 4412/4412 [==============================] - 2s 452us/step - loss: 0.0094 - val_loss: 0.0239
#
# Epoch 00015: val_loss did not improve from 0.01985
# Epoch 16/50
# 4412/4412 [==============================] - 2s 448us/step - loss: 0.0091 - val_loss: 0.0345
#
# Epoch 00016: val_loss did not improve from 0.01985
# Epoch 17/50
# 4412/4412 [==============================] - 2s 449us/step - loss: 0.0095 - val_loss: 0.0221
#
# Epoch 00017: val_loss did not improve from 0.01985
# Epoch 18/50
# 4412/4412 [==============================] - 2s 459us/step - loss: 0.0094 - val_loss: 0.0294
#
# Epoch 00018: val_loss did not improve from 0.01985
# Epoch 19/50
# 4412/4412 [==============================] - 2s 442us/step - loss: 0.0092 - val_loss: 0.0194
#
# Epoch 00019: val_loss improved from 0.01985 to 0.01939, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 20/50
# 4412/4412 [==============================] - 2s 454us/step - loss: 0.0089 - val_loss: 0.0231
#
# Epoch 00020: val_loss did not improve from 0.01939
# Epoch 21/50
# 4412/4412 [==============================] - 2s 468us/step - loss: 0.0092 - val_loss: 0.0230
#
# Epoch 00021: val_loss did not improve from 0.01939
# Epoch 22/50
# 4412/4412 [==============================] - 2s 448us/step - loss: 0.0090 - val_loss: 0.0348
#
# Epoch 00022: val_loss did not improve from 0.01939
# Epoch 23/50
# 4412/4412 [==============================] - 2s 450us/step - loss: 0.0093 - val_loss: 0.0231
#
# Epoch 00023: val_loss did not improve from 0.01939
# Epoch 24/50
# 4412/4412 [==============================] - 2s 451us/step - loss: 0.0092 - val_loss: 0.0249
#
# Epoch 00024: val_loss did not improve from 0.01939
# Epoch 25/50
# 4412/4412 [==============================] - 2s 454us/step - loss: 0.0091 - val_loss: 0.0323
#
# Epoch 00025: val_loss did not improve from 0.01939
# Epoch 26/50
# 4412/4412 [==============================] - 2s 442us/step - loss: 0.0091 - val_loss: 0.0273
#
# Epoch 00026: val_loss did not improve from 0.01939
# Epoch 27/50
# 4412/4412 [==============================] - 2s 443us/step - loss: 0.0090 - val_loss: 0.0242
#
# Epoch 00027: val_loss did not improve from 0.01939
# Epoch 28/50
# 4412/4412 [==============================] - 2s 457us/step - loss: 0.0086 - val_loss: 0.0231
#
# Epoch 00028: val_loss did not improve from 0.01939
# Epoch 29/50
# 4412/4412 [==============================] - 2s 463us/step - loss: 0.0085 - val_loss: 0.0315
#
# Epoch 00029: val_loss did not improve from 0.01939
# Epoch 30/50
# 4412/4412 [==============================] - 2s 454us/step - loss: 0.0085 - val_loss: 0.0254
#
# Epoch 00030: val_loss did not improve from 0.01939
# Epoch 31/50
# 4412/4412 [==============================] - 2s 456us/step - loss: 0.0087 - val_loss: 0.0286
#
# Epoch 00031: val_loss did not improve from 0.01939
# Epoch 32/50
# 4412/4412 [==============================] - 2s 446us/step - loss: 0.0087 - val_loss: 0.0262
#
# Epoch 00032: val_loss did not improve from 0.01939
# Epoch 33/50
# 4412/4412 [==============================] - 2s 450us/step - loss: 0.0084 - val_loss: 0.0263
#
# Epoch 00033: val_loss did not improve from 0.01939
# Epoch 34/50
# 4412/4412 [==============================] - 2s 446us/step - loss: 0.0082 - val_loss: 0.0291
#
# Epoch 00034: val_loss did not improve from 0.01939
# Epoch 35/50
# 4412/4412 [==============================] - 2s 442us/step - loss: 0.0085 - val_loss: 0.0202
#
# Epoch 00035: val_loss did not improve from 0.01939
# Epoch 36/50
# 4412/4412 [==============================] - 2s 451us/step - loss: 0.0081 - val_loss: 0.0309
#
# Epoch 00036: val_loss did not improve from 0.01939
# Epoch 37/50
# 4412/4412 [==============================] - 2s 450us/step - loss: 0.0084 - val_loss: 0.0294
#
# Epoch 00037: val_loss did not improve from 0.01939
# Epoch 38/50
# 4412/4412 [==============================] - 2s 445us/step - loss: 0.0085 - val_loss: 0.0251
#
# Epoch 00038: val_loss did not improve from 0.01939
# Epoch 39/50
# 4412/4412 [==============================] - 2s 443us/step - loss: 0.0084 - val_loss: 0.0220
#
# Epoch 00039: val_loss did not improve from 0.01939
# Epoch 40/50
# 4412/4412 [==============================] - 2s 465us/step - loss: 0.0080 - val_loss: 0.0172
#
# Epoch 00040: val_loss improved from 0.01939 to 0.01716, saving model to market_lstm_modelv4_weights.hdf5
# Epoch 41/50
# 4412/4412 [==============================] - 2s 466us/step - loss: 0.0078 - val_loss: 0.0229
#
# Epoch 00041: val_loss did not improve from 0.01716
# Epoch 42/50
# 4412/4412 [==============================] - 2s 449us/step - loss: 0.0081 - val_loss: 0.0238
#
# Epoch 00042: val_loss did not improve from 0.01716
# Epoch 43/50
# 4412/4412 [==============================] - 2s 447us/step - loss: 0.0077 - val_loss: 0.0209
#
# Epoch 00043: val_loss did not improve from 0.01716
# Epoch 44/50
# 4412/4412 [==============================] - 2s 448us/step - loss: 0.0074 - val_loss: 0.0207
#
# Epoch 00044: val_loss did not improve from 0.01716
# Epoch 45/50
# 4412/4412 [==============================] - 2s 450us/step - loss: 0.0078 - val_loss: 0.0253
#
# Epoch 00045: val_loss did not improve from 0.01716
# Epoch 46/50
# 4412/4412 [==============================] - 2s 455us/step - loss: 0.0080 - val_loss: 0.0254
#
# Epoch 00046: val_loss did not improve from 0.01716
# Epoch 47/50
# 4412/4412 [==============================] - 2s 450us/step - loss: 0.0078 - val_loss: 0.0298
#
# Epoch 00047: val_loss did not improve from 0.01716
# Epoch 48/50
# 4412/4412 [==============================] - 2s 449us/step - loss: 0.0076 - val_loss: 0.0202
#
# Epoch 00048: val_loss did not improve from 0.01716
# Epoch 49/50
# 4412/4412 [==============================] - 2s 440us/step - loss: 0.0076 - val_loss: 0.0209
#
# Epoch 00049: val_loss did not improve from 0.01716
# Epoch 50/50
# 4412/4412 [==============================] - 2s 443us/step - loss: 0.0075 - val_loss: 0.0249
#
# Epoch 00050: val_loss did not improve from 0.01716

# %%
# multi_model = Sequential()
# multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
# multi_model.add(Dense(1))
# multi_model.compile(loss='mae', optimizer='adam')

# Callbacks
# from keras.callbacks import ModelCheckpoint

# weight_path="{}_weights.hdf5".format('market_lstm_model')

# checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
#                              save_best_only=True, mode='min', save_weights_only = False)
# callbacks_list = [checkpoint]


# multi_history = multi_model.fit(train_X, train_y, epochs=40, batch_size=150, validation_data=(test_X, test_y), 
#                                 verbose=1, shuffle=False)#, callbacks = callbacks_list)

# %%
pyplot.plot(history.history['loss'], label='multi_train')
pyplot.plot(history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
yhat = model.predict(test_X)

# %%
test_y.shape
# Out:
# (1892, 8)

# %%
yhat.shape
# Out:
# (1892, 8)

# %%
#pyplot.plot(yhat[:,0][:,0], label='predict')
#pyplot.plot(test_y[:,0][:,0], label='true')
pyplot.plot(yhat[:,0], label='predict')
pyplot.plot(test_y[:,0], label='true')
pyplot.legend()
pyplot.show()

# %%
test_X.shape
# Out:
# (1892, 10, 8)

# %%
test_X.shape
# Out:
# (1892, 10, 8)

# %%
#reshape prediction
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1] * test_X.shape[2]))

#yhat.shape

#yhat = yhat.reshape((yhat.shape[0], yhat.shape[2]))

#test_X.shape

inv_yhat = concatenate((test_X[:, :], yhat), axis=1)

#inv_yhat.shape

inv_yhat = scaler.inverse_transform(inv_yhat)

#inv_yhat[:,-8:].shape

inv_yhat = inv_yhat[:,-8:]

#inv_yhat.shape

# %%
test_y.shape
# Out:
# (1892, 8)

# %%
inv_y = concatenate((test_X[:, :], test_y), axis=1)

#inv_y.shape

inv_y = scaler.inverse_transform(inv_y)

inv_y[:,-8:].shape

inv_y = inv_y[:,-8:]

#inv_y.shape

# %%
rmse = sqrt(mean_squared_error(test_y[:,0], yhat[:,0]))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.035

# %%
rmse = sqrt(mean_squared_error(inv_y[:,0], inv_yhat[:,0]))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 93.635

# %%
predictDates = data.tail(len(inv_y)).index
actual_chart = go.Scatter(x=predictDates, y=inv_y[:,0], name= 'Actual Price')
multi_predict_chart = go.Scatter(x=predictDates, y=inv_yhat[:,0], name= 'Multi Predict Price')
py.iplot([multi_predict_chart, actual_chart])
# Out:
# <div id="79ef2652-2f61-4295-8a0c-03903297d121" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("79ef2652-2f61-4295-8a0c-03903297d121", [{"name": "Multi Predict Price", "x": [20110502, 20110503, 20110504, 20110505, 20110506, 20110509, 20110510, 20110511, 20110512, 20110513, 20110516, 20110517, 20110518, 20110519, 20110520, 20110523, 20110524, 20110525, 20110526, 20110527, 20110531, 20110601, 20110602, 20110603, 20110606, 20110607, 20110608, 20110609, 20110610, 20110613, 20110614, 20110615, 20110616, 20110617, 20110620, 20110621, 20110622, 20110623, 20110624, 20110627, 20110628, 20110629, 20110630, 20110701, 20110705, 20110706, 20110707, 20110708, 20110711, 20110712, 20110713, 20110714, 20110715, 20110718, 20110719, 20110720, 20110721, 20110722, 20110725, 20110726, 20110727, 20110728, 20110729, 20110801, 20110802, 20110803, 20110804, 20110805, 20110808, 20110809, 20110810, 20110811, 20110812, 20110815, 20110816, 20110817, 20110818, 20110819, 20110822, 20110823, 20110824, 20110825, 20110826, 20110829, 20110830, 20110831, 20110901, 20110902, 20110906, 20110907, 20110908, 20110909, 20110912, 20110913, 20110914, 20110915, 20110916, 20110919, 20110920, 20110921, 20110922, 20110923, 20110926, 20110927, 20110928, 20110929, 20110930, 20111003, 20111004, 20111005, 20111006, 20111007, 20111010, 20111011, 20111012, 20111013, 20111014, 20111017, 20111018, 20111019, 20111020, 20111021, 20111024, 20111025, 20111026, 20111027, 20111028, 20111031, 20111101, 20111102, 20111103, 20111104, 20111107, 20111108, 20111109, 20111110, 20111111, 20111114, 20111115, 20111116, 20111117, 20111118, 20111121, 20111122, 20111123, 20111125, 20111128, 20111129, 20111130, 20111201, 20111202, 20111205, 20111206, 20111207, 20111208, 20111209, 20111212, 20111213, 20111214, 20111215, 20111216, 20111219, 20111220, 20111221, 20111222, 20111223, 20111227, 20111228, 20111229, 20111230, 20120103, 20120104, 20120105, 20120106, 20120109, 20120110, 20120111, 20120112, 20120113, 20120117, 20120118, 20120119, 20120120, 20120123, 20120124, 20120125, 20120126, 20120127, 20120130, 20120131, 20120201, 20120202, 20120203, 20120206, 20120207, 20120208, 20120209, 20120210, 20120213, 20120214, 20120215, 20120216, 20120217, 20120221, 20120222, 20120223, 20120224, 20120227, 20120228, 20120229, 20120301, 20120302, 20120305, 20120306, 20120307, 20120308, 20120309, 20120312, 20120313, 20120314, 20120315, 20120316, 20120319, 20120320, 20120321, 20120322, 20120323, 20120326, 20120327, 20120328, 20120329, 20120330, 20120402, 20120403, 20120404, 20120405, 20120409, 20120410, 20120411, 20120412, 20120413, 20120416, 20120417, 20120418, 20120419, 20120420, 20120423, 20120424, 20120425, 20120426, 20120427, 20120430, 20120501, 20120502, 20120503, 20120504, 20120507, 20120508, 20120509, 20120510, 20120511, 20120514, 20120515, 20120516, 20120517, 20120518, 20120521, 20120522, 20120523, 20120524, 20120525, 20120529, 20120530, 20120531, 20120601, 20120604, 20120605, 20120606, 20120607, 20120608, 20120611, 20120612, 20120613, 20120614, 20120615, 20120618, 20120619, 20120620, 20120621, 20120622, 20120625, 20120626, 20120627, 20120628, 20120629, 20120702, 20120703, 20120705, 20120706, 20120709, 20120710, 20120711, 20120712, 20120713, 20120716, 20120717, 20120718, 20120719, 20120720, 20120723, 20120724, 20120725, 20120726, 20120727, 20120730, 20120731, 20120801, 20120802, 20120803, 20120806, 20120807, 20120808, 20120809, 20120810, 20120813, 20120814, 20120815, 20120816, 20120817, 20120820, 20120821, 20120822, 20120823, 20120824, 20120827, 20120828, 20120829, 20120830, 20120831, 20120904, 20120905, 20120906, 20120907, 20120910, 20120911, 20120912, 20120913, 20120914, 20120917, 20120918, 20120919, 20120920, 20120921, 20120924, 20120925, 20120926, 20120927, 20120928, 20121001, 20121002, 20121003, 20121004, 20121005, 20121008 ...
